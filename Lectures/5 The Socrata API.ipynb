# %% [markdown]
# # The Socrata API

# %% [markdown]
# ## Lecture objectives
#
# 1. Learn how to use the Socrata API
# 2. More practice with `pandas`, `geopandas`, and plotting

# %% [markdown]
# ### Socrata
# Many cities, other government agencies, and nonprofit organizations make their data available through the Socrata API. The City of Los Angeles is one user. [You can browse the city's datasets here](https://data.lacity.org).
#
# Just like the census, you can call Socrata APIs with `requests`, but there is also a dedicated package, `sodapy`.
#
# [Look at the housing dataset here](https://data.lacity.org/Housing-and-Real-Estate/HCIDLA-Affordable-Housing-Projects-List-2003-to-Pr/mymu-zi3s). Click on the API button in the top right corner. You can see much useful information:
#
# * The URL (the API endpoint)
# * The format (JSON is the default)
# * Some helpful links
#
# Let's copy and paste the API endpoint, and use `requests`.

# %%
import requests
import pandas as pd
import json

url = 'https://data.lacity.org/resource/mymu-zi3s.json'
r = requests.get(url)
df = pd.DataFrame(json.loads(r.text))
df
# Out:
#             apn project_number                                 name  \
# 0    5143020023      02-118256                 SAN LUCAS APARTMENTS
# 1    5537023034          70159                       HARVARD CIRCLE
# 2    6032019034      14-121272           MARTHA BRYANT MANOR- RECAP
# 3    5050011005      05-117193               LEEWARD APTS. (SITE 7)
# 4    5114014020      14-121652              FLORENCE MILLS (SITE 5)
# ..          ...            ...                                  ...
# 539  2604028031      19-125927  SILVA CROSSING (FKA LINK AT SYLMAR)
# 540  5149010949      18-124964          GRAND AVENUE PARCEL Q APTS.
# 541  5114014004      14-121652              FLORENCE MILLS (SITE 4)
# 542  5183005010      09-117211              LAS MARGARITAS (SITE 2)
# 543  5153006024          50035                          UNION POINT
#
#     development_stage                construction_type  \
# 0          In-Service                 NEW CONSTRUCTION
# 1          In-Service                 NEW CONSTRUCTION
# 2          In-Service              ACQUISITION + REHAB
# 3          In-Service                            REHAB
# 4          In-Service                 NEW CONSTRUCTION
# ..                ...                              ...
# 539       Development                 NEW CONSTRUCTION
# 540       Development            DEMO/NEW CONSTRUCTION
# 541        In-Service                 NEW CONSTRUCTION
# 542        In-Service  BOTH REHAB AND NEW CONSTRUCTION
# 543        In-Service                 NEW CONSTRUCTION
#
#                                                address council_district  \
# 0                 1221 W 7TH ST  Los Angeles, CA 90017                1
# 1       952 N HARVARD BLVD 1-40  LOS ANGELES, CA 90029               13
# 2              8300 S HOOVER ST  Los Angeles, CA 90044                8
# 3              2809 S WEST BLVD  Los Angeles, CA 90016               10
# 4    1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...                9
# ..                                                 ...              ...
# 539          12667 SAN FERNANDO ROAD  Sylmar, CA 91342                7
# 540             100 S GRAND AVE  Los Angeles, CA 90012               14
# 541          3509 S CENTRAL AVE  LOS ANGELES, CA 90011                9
# 542               115 N SOTO ST  Los Angeles, CA 90033               14
# 543         420 S UNION DR 1-21  Los Angeles, CA 90017                1
#
#     site_cd          community site_units  ...  latitude  \
# 0         1           WESTLAKE        196  ...  34.05209
# 1         1            MELROSE         40  ...   34.0884
# 2         1      VERMONT VISTA         77  ...  33.96297
# 3         7  CRENSHAW DISTRICT          0  ...  34.03071
# 4         5            CENTRAL          0  ...  34.01115
# ..      ...                ...        ...  ...       ...
# 539       1             SYLMAR         56  ...  34.29927
# 540       1           DOWNTOWN        323  ...   34.0549
# 541       4            CENTRAL          0  ...  34.01136
# 542       2      BOYLE HEIGHTS          0  ...  34.04422
# 543       1           WESTLAKE         21  ...  34.05845
#
#                                        geocoded_column  \
# 0    {'type': 'Point', 'coordinates': [-118.26681, ...
# 1    {'type': 'Point', 'coordinates': [-118.30371, ...
# 2    {'type': 'Point', 'coordinates': [-118.28691, ...
# 3    {'type': 'Point', 'coordinates': [-118.34182, ...
# 4    {'type': 'Point', 'coordinates': [-118.25748, ...
# ..                                                 ...
# 539  {'type': 'Point', 'coordinates': [-118.45975, ...
# 540  {'type': 'Point', 'coordinates': [-118.24805, ...
# 541  {'type': 'Point', 'coordinates': [-118.2567, 3...
# 542  {'type': 'Point', 'coordinates': [-118.20967, ...
# 543  {'type': 'Point', 'coordinates': [-118.26768, ...
#
#     :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv  \
# 0                         23078                         564
# 1                         23447                         439
# 2                         23675                         783
# 3                         23077                         668
# 4                         22727                         712
# ..                          ...                         ...
# 539                       18912                          51
# 540                       22728                         543
# 541                       22727                         712
# 542                       23450                         522
# 543                       23078                         564
#
#     :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx  \
# 0                          1047                          54
# 1                           929                         NaN
# 2                          1005                           7
# 3                           925                           7
# 4                           892                           7
# ..                          ...                         ...
# 539                         642                         NaN
# 540                        1183                          37
# 541                         892                           7
# 542                         350                         NaN
# 543                        1047                         NaN
#
#     :@computed_region_kqwf_mjcx :@computed_region_2dna_qi2s jobs  \
# 0                            11                          76  NaN
# 1                             8                          58  142
# 2                            14                          45  NaN
# 3                            12                          17  NaN
# 4                            13                           6  226
# ..                          ...                         ...  ...
# 539                           1                          47  234
# 540                           9                          76  NaN
# 541                          13                           6  226
# 542                           9                          38  121
# 543                          11                          67   40
#
#     contract_numbers
# 0                NaN
# 1           C-113118
# 2                NaN
# 3                NaN
# 4           C-129358
# ..               ...
# 539         C-137141
# 540              NaN
# 541         C-129358
# 542         C-117254
# 543         C-109529
#
# [544 rows x 36 columns]

# %% [markdown]
# We might have expected some geographic coordinates, and it looks like they are in the `geocoded_column` column.
#
# We converted it to a regular `pandas` DataFrame, which doesn't understand spatial relationships. So how do we make the geometries readily available?
#
# Looking back at the [webpage](https://data.lacity.org/Housing-and-Real-Estate/HCIDLA-Affordable-Housing-Projects-List-2003-to-Pr/mymu-zi3s), the API also gives us a `geojson` option. How do we make use of this? Fortunately, the `geopandas.read_file()` function can read in the URL directly, without going through `requests`.
#
# Let's read the dataset into a `geoDataFrame` and call it `gdf`. Note that it gives us a `geometry` column with point locations.

# %%
import geopandas as gpd
url = 'https://data.lacity.org/resource/mymu-zi3s.geojson'
gdf = gpd.read_file(url)
gdf
# Out:
#     site_units tax_exempt_conduit_bond          community development_stage  \
# 0          196                       0           WESTLAKE        In-Service
# 1           40                       0            MELROSE        In-Service
# 2           77                 4410000      VERMONT VISTA        In-Service
# 3            0                10208936  CRENSHAW DISTRICT        In-Service
# 4            0                       0            CENTRAL        In-Service
# ..         ...                     ...                ...               ...
# 539         56                       0             SYLMAR       Development
# 540        323               184260433           DOWNTOWN       Development
# 541          0                       0            CENTRAL        In-Service
# 542          0                       0      BOYLE HEIGHTS        In-Service
# 543         21                       0           WESTLAKE        In-Service
#
#                                     name  leverage  latitude  \
# 0                   SAN LUCAS APARTMENTS         0  34.05209
# 1                         HARVARD CIRCLE  16436770   34.0884
# 2             MARTHA BRYANT MANOR- RECAP   7558174  33.96297
# 3                 LEEWARD APTS. (SITE 7)   7103994  34.03071
# 4                FLORENCE MILLS (SITE 5)  36081992  34.01115
# ..                                   ...       ...       ...
# 539  SILVA CROSSING (FKA LINK AT SYLMAR)  21433533  34.29927
# 540          GRAND AVENUE PARCEL Q APTS.  38757673   34.0549
# 541              FLORENCE MILLS (SITE 4)  36081992  34.01136
# 542              LAS MARGARITAS (SITE 2)  14135658  34.04422
# 543                          UNION POINT   5910494  34.05845
#
#                                                  photo project_number  \
# 0    {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      02-118256
# 1    {'url': 'http://hcidapp.lacity.org/mpphotos/07...          70159
# 2    {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      14-121272
# 3    {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      05-117193
# 4    {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      14-121652
# ..                                                 ...            ...
# 539  {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      19-125927
# 540  {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      18-124964
# 541  {'url': 'http://hcidapp.lacity.org/mpphotos/Im...      14-121652
# 542  {'url': 'http://hcidapp.lacity.org/mpphotos/09...      09-117211
# 543  {'url': 'http://hcidapp.lacity.org/mpphotos/05...          50035
#
#                                    developer  ... contract_numbers  \
# 0                                        N/A  ...             None
# 1                                        N/A  ...         C-113118
# 2                    BARKER MANAGEMENT, INC.  ...             None
# 3                   HAMPSTEAD PARTNERS, INC.  ...             None
# 4    Hollywood Community Housing Corporation  ...         C-129358
# ..                                       ...  ...              ...
# 539                 Meta Housing Corporation  ...         C-137141
# 540     Grand Avenue Parcel Q Developer, LLC  ...             None
# 541  Hollywood Community Housing Corporation  ...         C-129358
# 542          East L.A. Community Corporation  ...         C-117254
# 543                META HOUSING CORPORATION,  ...         C-109529
#
#                                                address         apn  \
# 0                 1221 W 7TH ST  Los Angeles, CA 90017  5143020023
# 1       952 N HARVARD BLVD 1-40  LOS ANGELES, CA 90029  5537023034
# 2              8300 S HOOVER ST  Los Angeles, CA 90044  6032019034
# 3              2809 S WEST BLVD  Los Angeles, CA 90016  5050011005
# 4    1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...  5114014020
# ..                                                 ...         ...
# 539          12667 SAN FERNANDO ROAD  Sylmar, CA 91342  2604028031
# 540             100 S GRAND AVE  Los Angeles, CA 90012  5149010949
# 541          3509 S CENTRAL AVE  LOS ANGELES, CA 90011  5114014004
# 542               115 N SOTO ST  Los Angeles, CA 90033  5183005010
# 543         420 S UNION DR 1-21  Los Angeles, CA 90017  5153006024
#
#     project_total_units                    housing_type  \
# 0                   196                         SENIORS
# 1                    40                          FAMILY
# 2                    77                          FAMILY
# 3                   257                          FAMILY
# 4                    74                   SPECIAL NEEDS
# ..                  ...                             ...
# 539                  56                   SPECIAL NEEDS
# 540                 323                          FAMILY
# 541                  74                   SPECIAL NEEDS
# 542                  42                          FAMILY
# 543                  21  LARGE FAMILY / WAIVER REQUIRED
#
#                   management_company supportive_housing council_district  \
# 0           GSL PROPERRTY MANAGEMENT                 No                1
# 1                FPI MANAGEMENT INC.                 No               13
# 2      LEVINE MANAGEMENT GROUP, INC.                 No                8
# 3    ALPHA PROPERTY MANAGEMENT, INC.                 No               10
# 4     BARKER MANAGEMENT INCORPORATED                Yes                9
# ..                               ...                ...              ...
# 539         THE JOHN STEWART COMPANY                Yes                7
# 540                              N/A                 No               14
# 541   BARKER MANAGEMENT INCORPORATED                Yes                9
# 542         THE JOHN STEWART COMPANY                 No               14
# 543         SOLARI ENTERPRISES, INC.                 No                1
#
#              tdc                     geometry
# 0              0  POINT (-118.26681 34.05209)
# 1       23222387  POINT (-118.30371 34.08840)
# 2       11968174  POINT (-118.28691 33.96297)
# 3       17312930  POINT (-118.34182 34.03071)
# 4    45471107.63  POINT (-118.25748 34.01115)
# ..           ...                          ...
# 539     30533533  POINT (-118.45975 34.29927)
# 540    223018106  POINT (-118.24805 34.05490)
# 541  45471107.63  POINT (-118.25670 34.01136)
# 542     14695419  POINT (-118.20967 34.04422)
# 543      8244494  POINT (-118.26768 34.05845)
#
# [544 rows x 30 columns]

# %% [markdown]
# We can check to see what projection it is in using the `crs` attribute. Then, we can plot the data.

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
gdf.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Before we clean up the map, let's mention two others way to read that data in–using the Socrata API.
#
# #### Sodapy
#
# We won't cover the [`sodapy` library](https://pypi.org/project/sodapy/) here, but it can be simpler for some types of dataset.
#
# #### Save to disk
# You can always point and click on the webpage, download the file to your computer, and load it in.
#
# Socrata gives you [various options for the format for this file](https://data.lacity.org/Housing-and-Real-Estate/HCIDLA-Affordable-Housing-Projects-List-2003-to-Pr/mymu-zi3s): `csv`, `shp`, and so on. Let's use the shapefile version.

# %%
# change this to whereever you download files on your computer
download_path = '/Users/adammb/Downloads/'
gpd.read_file(download_path+'LAHD Affordable Housing Projects List (2003 to Present)')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /Users/adammb/Downloads/LAHD Affordable Housing Projects List (2003 to Present): No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # change this to whereever you download files on your computer
#       2 download_path = '/Users/adammb/Downloads/'
# ----> 3 gpd.read_file(download_path+'LAHD Affordable Housing Projects List (2003 to Present)')
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/geopandas/io/file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     198     reader = fiona.open
#     200 with fiona_env():
# --> 201     with reader(path_or_bytes, **kwargs) as features:
#     202
#     203         # In a future Fiona release the crs attribute of features will
#     204         # no longer be a dict, but will behave like a dict. So this should
#     205         # be forwards compatible
#     206         crs = (
#     207             features.crs["init"]
#     208             if features.crs and "init" in features.crs
#     209             else features.crs_wkt
#     210         )
#     212         # handle loading the bounding box
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/fiona/env.py:408, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwargs)
#     405 @wraps(f)
#     406 def wrapper(*args, **kwargs):
#     407     if local._env:
# --> 408         return f(*args, **kwargs)
#     409     else:
#     410         if isinstance(args[0], str):
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/fiona/__init__.py:264, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     261     path = parse_path(fp)
#     263 if mode in ('a', 'r'):
# --> 264     c = Collection(path, mode, driver=driver, encoding=encoding,
#     265                    layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     266 elif mode == 'w':
#     267     if schema:
#     268         # Make an ordered dict of schema properties.
#
# File /opt/anaconda3/envs/uds/lib/python3.8/site-packages/fiona/collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160 if self.mode == 'r':
#     161     self.session = Session()
# --> 162     self.session.start(self, **kwargs)
#     163 elif self.mode in ('a', 'w'):
#     164     self.session = WritingSession()
#
# File fiona/ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona/_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: /Users/adammb/Downloads/LAHD Affordable Housing Projects List (2003 to Present): No such file or directory

# %% [markdown]
# Now let's clean up the map. First, note that we can call `gdf.plot()` directly, but we have more flexibility if we create our own figure and axis object using `plt.subplots()`.
#
# Let's also plot the data in a particular column, perhaps `site_units`, as a proportional circle.
#
# And finally, let's use `contextily` to provide a basemap.

# %%
import matplotlib.pyplot as plt
import contextily as ctx
# If we try to plot site_units, we get an error due to the zero-unit entries. Let's solve that first.
gdf['site_units'] = gdf.site_units.astype(int)  # convert to integer

fig, ax = plt.subplots(figsize=(10,10))

# basemaps are typically in Web Mercator (projection 3857), so we need to reproject our dataframe to this
gdf[gdf.site_units>0].to_crs('EPSG:3857').plot(markersize='site_units', ax=ax)

# let's add a basemap using the contextily library. The zoom was trial and error
ctx.add_basemap(ax, zoom=12)

# and we really don't need the axis ticks and labels, so we set them to an empty list
ax.set_xticks([])
ax.set_yticks([])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Key Takeaways</h3>
# <ul>
#   <li>Government open data sites often use Socrata.</li>
#   <li>The data format is usually well documented, and there are several options to import it to Python.</li>
#   <li>When importing geospatial data, pay attention to the projection.</li>
# </ul>
# </div>
