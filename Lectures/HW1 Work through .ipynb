# %% [markdown]
# ## Question 1

# %%
import json
import pandas as pd
import requests

APIkey = 'MW9S-E7SL-26DU-VV8V'  # the key posted on BART's website
requestString = 'https://api.bart.gov/api/stn.aspx?cmd=stns&key=MW9S-E7SL-26DU-VV8V&json=y'.format(APIkey)
r = requests.get(requestString)
#print(r.text)

# %%
d = json.loads(r.text)
print(type(d))
# Out:
# <class 'dict'>

# %%
print(d.keys())
print(d['root'])
# Out:
# dict_keys(['?xml', 'root'])
# ...

# %%
print((d['root'].keys()))
# Out:
# dict_keys(['uri', 'stations', 'message'])

# %%
print(type((d['root']['stations']['station'])))
# Out:
# <class 'list'>

# %%
print(len(d['root']['stations']['station']))
# Out:
# 50

# %%
print(len(d['root']['stations']))
print(d['root']['stations']['station'][0])
# Out:
# 1
# {'name': '12th St. Oakland City Center', 'abbr': '12TH', 'gtfs_latitude': '37.803768', 'gtfs_longitude': '-122.271450', 'address': '1245 Broadway', 'city': 'Oakland', 'county': 'alameda', 'state': 'CA', 'zipcode': '94612'}

# %%
stations = d['root']['stations']['station'][0:50]

print(stations[0])
# Out:
# {'name': '12th St. Oakland City Center', 'abbr': '12TH', 'gtfs_latitude': '37.803768', 'gtfs_longitude': '-122.271450', 'address': '1245 Broadway', 'city': 'Oakland', 'county': 'alameda', 'state': 'CA', 'zipcode': '94612'}

# %%
df = pd.DataFrame(stations)
df
# Out:
#                                    name  abbr gtfs_latitude gtfs_longitude  \
# 0          12th St. Oakland City Center  12TH     37.803768    -122.271450
# 1                      16th St. Mission  16TH     37.765062    -122.419694
# 2                      19th St. Oakland  19TH     37.808350    -122.268602
# 3                      24th St. Mission  24TH     37.752470    -122.418143
# 4                               Antioch  ANTC     37.995388    -121.780420
# 5                                 Ashby  ASHB     37.852803    -122.270062
# 6                           Balboa Park  BALB     37.721585    -122.447506
# 7                              Bay Fair  BAYF     37.696924    -122.126514
# 8              Berryessa/North San Jose  BERY     37.368473    -121.874681
# 9                         Castro Valley  CAST     37.690746    -122.075602
# 10                Civic Center/UN Plaza  CIVC     37.779732    -122.414123
# ...

# %% [markdown]
# ## Question 2

# %%
requestString = 'http://api.bart.gov/api/sched.aspx?cmd=fare&orig=phil&dest=woak&key={}&json=y'.format(APIkey)
r = requests.get(requestString)
print(r.text)
# Out:
# {"?xml":{"@version":"1.0","@encoding":"utf-8"},"root":{"uri":{"#cdata-section":"http://api.bart.gov/api/sched.aspx?cmd=fare&orig=phil&dest=woak&json=y"},"origin":"PHIL","destination":"WOAK","trip":{"fare":"4.10","discount":{"clipper":"1.50"}},"fares":{"@level":"normal","fare":[{"@amount":"4.10","@class":"clipper","@name":"Clipper"},{"@amount":"3.25","@class":"start","@name":"Clipper START"},{"@amount":"1.50","@class":"rtcclipper","@name":"Senior/Disabled Clipper"},{"@amount":"2.05","@class":"student","@name":"Youth Clipper"}]},"message":""}}

# %%
d = json.loads(r.text)
print(type(d))
# Out:
# <class 'dict'>

# %%
print(d.keys())
print(d['root'])
# Out:
# dict_keys(['?xml', 'root'])
# {'uri': {'#cdata-section': 'http://api.bart.gov/api/sched.aspx?cmd=fare&orig=phil&dest=woak&json=y'}, 'origin': 'PHIL', 'destination': 'WOAK', 'trip': {'fare': '4.10', 'discount': {'clipper': '1.50'}}, 'fares': {'@level': 'normal', 'fare': [{'@amount': '4.10', '@class': 'clipper', '@name': 'Clipper'}, {'@amount': '3.25', '@class': 'start', '@name': 'Clipper START'}, {'@amount': '1.50', '@class': 'rtcclipper', '@name': 'Senior/Disabled Clipper'}, {'@amount': '2.05', '@class': 'student', '@name': 'Youth Clipper'}]}, 'message': ''}

# %%
print(type((d['root']['trip']['fare'])))
# Out:
# <class 'str'>

# %%
fare = d['root']['trip']['fare'] # replace with your answer
print('The fare is ${}'.format(fare))
# Out:
# The fare is $4.10

# %% [markdown]
# #### All together now

# %%
requestString = 'http://api.bart.gov/api/sched.aspx?cmd=fare&orig=phil&dest=woak&key={}&json=y'.format(APIkey)
r = requests.get(requestString)
d = json.loads(r.text)
fare = d['root']['trip']['fare'] 
print('The fare is ${}'.format(fare))
# Out:
# The fare is $4.10

# %% [markdown]
# ## Question 3

# %%
### your code here

def woak_fare(orig):
    # contents of your function here
    fare = 999 # replace with your code here
    return fare

# example
print('Fare to Civic Center is ${}'.format(woak_fare('CIVC')))

# %%
def woak_fare(orig):
    requestString = 'http://api.bart.gov/api/sched.aspx?cmd=fare&orig={}&dest=woak&key={}&json=y'.format(orig, APIkey)
    r = requests.get(requestString)
    d = json.loads(r.text)
    fare = d['root']['trip']['fare'] 
    return fare

# %%
print('Fare to Civic Center is ${}'.format(woak_fare('CIVC')))
print('Fare to Warm Springs/South Fremont is ${}'.format(woak_fare('WARM')))
# Out:
# Fare to Civic Center is $3.45
# Fare to Warm Springs/South Fremont is $5.35

# %%
#All together
def woak_fare(orig):
    requestString = 'http://api.bart.gov/api/sched.aspx?cmd=fare&orig={}&dest=woak&key={}&json=y'.format(orig, APIkey)
    r = requests.get(requestString)
    d = json.loads(r.text)
    fare = d['root']['trip']['fare'] 
    return fare

print('Fare to Civic Center is ${}'.format(woak_fare('CIVC')))
print('Fare to Warm Springs/South Fremont is ${}'.format(woak_fare('WARM')))
# Out:
# Fare to Civic Center is $3.45
# Fare to Warm Springs/South Fremont is $5.35

# %% [markdown]
# ## Q4

# %%
import cenpy
from cenpy import products

# create a connection to the American Community Survey
acs = cenpy.products.ACS()

# %%
# get all the tables that have "MEDIAN HOUSEHOLD INCOME" in their description
acs.filter_tables('MEDIAN HOUSEHOLD INCOME', by='description')
# Out:
#                                                   description  \
# table_name
# B19013      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B19019      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B19049      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B22008      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B25099      MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN ...
# B25119      MEDIAN HOUSEHOLD INCOME THE PAST 12 MONTHS (IN...
#
#                                                       columns
# table_name
# B19013                                          [B19013_001E]
# B19019      [B19019_001E, B19019_002E, B19019_003E, B19019...
# B19049      [B19049_001E, B19049_002E, B19049_003E, B19049...
# B22008                [B22008_001E, B22008_002E, B22008_003E]
# B25099                [B25099_001E, B25099_002E, B25099_003E]
# B25119                [B25119_001E, B25119_002E, B25119_003E]

# %%
income_tables = acs.filter_tables('MEDIAN HOUSEHOLD INCOME', by='description') # replace 999 with your code here
print(income_tables)
# Out:
#                                                   description  \
# table_name
# B19013      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B19019      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B19049      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B22008      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# B25099      MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN ...
# B25119      MEDIAN HOUSEHOLD INCOME THE PAST 12 MONTHS (IN...
#
#                                                       columns
# table_name
# B19013                                          [B19013_001E]
# B19019      [B19019_001E, B19019_002E, B19019_003E, B19019...
# B19049      [B19049_001E, B19049_002E, B19049_003E, B19049...
# B22008                [B22008_001E, B22008_002E, B22008_003E]
# B25099                [B25099_001E, B25099_002E, B25099_003E]
# B25119                [B25119_001E, B25119_002E, B25119_003E]

# %%
import cenpy
from cenpy import products

# create a connection to the American Community Survey
acs = cenpy.products.ACS()
# get all the tables that have "MEDIAN HOUSEHOLD INCOME" in their description
acs.filter_tables('MEDIAN HOUSEHOLD INCOME', by='description')
# print tables 
income_tables = acs.filter_tables('MEDIAN HOUSEHOLD INCOME', by='description') # replace 999 with your code here
print(income_tables)
# Out:
#                                                                                                                                         description  \
# table_name
# B19013                                                           MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)
# B19019                                         MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY HOUSEHOLD SIZE
# B19049                                     MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER
# B22008      MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS
# B25099                                        MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)
# ...

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
# Autograding tests - do not edit
assert len(income_tables) == 6
assert 'B19013' in income_tables.index.values

# %%
acs.filter_variables('B19019_001E')
# Out:
#                        label  \
# B19019_001E  Estimate!!Total
#
#                                                                                                           concept  \
# B19019_001E  MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY HOUSEHOLD SIZE
#
#             predicateType   group limit predicateOnly hasGeoCollectionSupport  \
# B19019_001E           int  B19019     0           NaN                     NaN
#
#                                         attributes required values
# B19019_001E  B19019_001EA,B19019_001M,B19019_001MA      NaN    NaN

# %% [markdown]
# ## Q5

# %%
import cenpy
import json
import requests
import pandas as pd
import geopandas as gpd
from cenpy import products

# create a connection to the American Community Survey
acs = cenpy.products.ACS()
gdf = products.ACS(2017).from_place('Oakland, CA', level='tract', variables='B19019_001E')
gdf = gpd.GeoDataFrame(gdf, geometry = 'geometry')
print(gdf)
# Out:
# /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# Matched: Oakland, CA to Oakland city within layer Incorporated Places
# /opt/anaconda3/envs/uds/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:1981: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   result[:] = values
# ...

# %%
# Autograding tests - do not edit
assert len(gdf) == 71
assert list(gdf.columns)==['GEOID', 'geometry', 'B19019_001E', 'state', 'county','tract']

# %% [markdown]
# ## Q6

# %%
gdf.rename(columns={'B19019_001E':'Median Household Income'}, inplace=True)
gdf.head()
# Out:
#          GEOID  \
# 0  06001402400
# 1  06001402900
# 2  06001401200
# 3  06001403400
# 4  06001400300
#
# ...

# %%
max_tract_income = gdf['Median Household Income'].max()
print(max_tract_income)
# Out:
# 115563.0

# %% [markdown]
# ## Q7

# %%
import matplotlib.pyplot as plt
import contextily as ctx

fig, ax = plt.subplots(1,1,figsize=(10,10))

gdf.to_crs('EPSG:3857').plot('Median Household Income', ax=ax, markersize=2,  cmap='plasma', legend=True, 
               legend_kwds={'orientation': 'vertical'})
ax.set_facecolor('k')
ctx.add_basemap(ax=ax, zoom=12, source=ctx.providers.OpenStreetMap.Mapnik)
ax.set_xticks([])
ax.set_yticks([])
ax.set_title('Median Household Income, City of Oakland')
# Out:
# Text(0.5, 1.0, 'Median Household Income, City of Oakland')

# %% [markdown]
# ## Challenge Question

# %% [markdown]
# Remember, you need to do at least two of these challenge problems during the quarter.
#
# Look at the US EPA AirNow API. You'll need to register for your own API key - click on Log In and follow the steps to request an account. You'll get your key within a minute.
#
# Once you a logged in, look at the Web Services, and then Observations by Monitoring Site. If you click on the Query Tool, you can build up a query in the point-and-click interface. This will help you understand the API syntax.
#
# Back in Python, use the requests library to get all the data for PM 2.5 for each day in 2021, in the approximate LA County area (you might have to play around with the bounding box). Return this as a pandas dataframe.
#
# Put this in a function that takes at least one argument. For example, you could write a function where you pass the year, or the pollutant type. Your function should return a dataframe with the results of your API query.
#
# Then, map or plot the data in whatever way you choose (e.g. boxplots or line charts of pollution levels).
#
# If you want to map it, here's some advice on how to convert a pandas dataframe into a geodataframe, using the lat and lon columns returned by the API.

# %%
import json
import pandas as pd
import requests
import geopandas 

requestString = 'https://www.airnowapi.org/aq/data/?startDate=2021-01-01T03&endDate=2021-12-01T03&parameters=PM25&BBOX=-118.252950,33.802289,-118.046956,33.993788&dataType=C&format=application/json&verbose=0&monitorType=0&includerawconcentrations=0&API_KEY=4D443089-5C44-482F-8311-A46004897DA2'
r = requests.get(requestString)
d = json.loads(r.text)

df = pd.DataFrame(d) #convert to dataframe

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
gdf
# Out:
#       Latitude  Longitude               UTC Parameter   Unit  Value  \
# 0      33.9014   -118.205  2021-01-01T03:00     PM2.5  UG/M3   17.7
# 1      33.9014   -118.205  2021-01-01T04:00     PM2.5  UG/M3   61.8
# 2      33.9014   -118.205  2021-01-01T05:00     PM2.5  UG/M3   82.6
# 3      33.9014   -118.205  2021-01-01T06:00     PM2.5  UG/M3  120.2
# 4      33.9014   -118.205  2021-01-01T07:00     PM2.5  UG/M3  162.2
# ...        ...        ...               ...       ...    ...    ...
# 7816   33.9014   -118.205  2021-11-30T23:00     PM2.5  UG/M3   42.7
# 7817   33.9014   -118.205  2021-12-01T00:00     PM2.5  UG/M3   42.2
# 7818   33.9014   -118.205  2021-12-01T01:00     PM2.5  UG/M3   38.6
# 7819   33.9014   -118.205  2021-12-01T02:00     PM2.5  UG/M3   38.1
# 7820   33.9014   -118.205  2021-12-01T03:00     PM2.5  UG/M3   36.2
#
#                          geometry
# 0     POINT (-118.20500 33.90140)
# 1     POINT (-118.20500 33.90140)
# 2     POINT (-118.20500 33.90140)
# ...

# %%
import json
import pandas as pd
import requests
import geopandas 

requestString = 'https://www.airnowapi.org/aq/data/?startDate=2021-01-01T03&endDate=2021-12-31T03&parameters=PM25&BBOX=-118.448108,33.949086,-117.885058,34.219782&dataType=C&format=application/json&verbose=0&monitorType=0&includerawconcentrations=0&API_KEY=4D443089-5C44-482F-8311-A46004897DA2'
r = requests.get(requestString)
d = json.loads(r.text)

df = pd.DataFrame(d) #convert to dataframe
df
# Out:
#        Latitude   Longitude               UTC Parameter   Unit  Value
# 0     34.181977 -118.363036  2021-01-01T03:00     PM2.5  UG/M3    6.0
# 1     34.181977 -118.363036  2021-01-01T04:00     PM2.5  UG/M3    8.9
# 2     34.181977 -118.363036  2021-01-01T05:00     PM2.5  UG/M3   14.6
# 3     34.181977 -118.363036  2021-01-01T06:00     PM2.5  UG/M3   13.6
# 4     34.181977 -118.363036  2021-01-01T07:00     PM2.5  UG/M3   18.8
# ...         ...         ...               ...       ...    ...    ...
# 8580  34.181977 -118.363036  2021-12-30T23:00     PM2.5  UG/M3    7.0
# 8581  34.181977 -118.363036  2021-12-31T00:00     PM2.5  UG/M3    6.0
# 8582  34.181977 -118.363036  2021-12-31T01:00     PM2.5  UG/M3    5.8
# 8583  34.181977 -118.363036  2021-12-31T02:00     PM2.5  UG/M3    6.9
# 8584  34.181977 -118.363036  2021-12-31T03:00     PM2.5  UG/M3    6.8
#
# [8585 rows x 6 columns]

# %%
import json
import pandas as pd
import requests
import geopandas 

requestString = 'https://www.airnowapi.org/aq/data/?startDate=2021-01-01T03&endDate=2021-12-31T03&parameters=PM25&BBOX=-118.495522,33.927767,-117.847328,34.255303&dataType=C&format=application/json&verbose=0&monitorType=0&includerawconcentrations=0&API_KEY=4D443089-5C44-482F-8311-A46004897DA2'
r = requests.get(requestString)
d = json.loads(r.text)

df = pd.DataFrame(d) #convert to dataframe
df
# Out:
#         Latitude   Longitude               UTC Parameter   Unit  Value
# 0      34.181977 -118.363036  2021-01-01T03:00     PM2.5  UG/M3    6.0
# 1      34.143900 -117.850800  2021-01-01T03:00     PM2.5  UG/M3    4.8
# 2      34.181977 -118.363036  2021-01-01T04:00     PM2.5  UG/M3    8.9
# 3      34.143900 -117.850800  2021-01-01T04:00     PM2.5  UG/M3    9.8
# 4      34.181977 -118.363036  2021-01-01T05:00     PM2.5  UG/M3   14.6
# ...          ...         ...               ...       ...    ...    ...
# 16782  34.143900 -117.850800  2021-12-31T01:00     PM2.5  UG/M3    3.5
# 16783  34.181977 -118.363036  2021-12-31T02:00     PM2.5  UG/M3    6.9
# 16784  34.143900 -117.850800  2021-12-31T02:00     PM2.5  UG/M3    1.8
# 16785  34.181977 -118.363036  2021-12-31T03:00     PM2.5  UG/M3    6.8
# 16786  34.143900 -117.850800  2021-12-31T03:00     PM2.5  UG/M3    0.3
#
# [16787 rows x 6 columns]
